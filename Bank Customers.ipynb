# %% [markdown]
# About the Dataset:
#
#     This dataset consists of 14 columns and 10000 rows which has the details like Name of the customer, Age of the customer,
#     whether the customer is having credit card or not and many more.
#
# Aim:
#
#     The main aim of this problem is to predict whether the customer of the bank exits the bank or not which can be predicted
#     using the details given in the dataset. This is a binary classification problem because we are going to predict whether the
#     customer leaves the bank or not.

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\SRIRAM\\Desktop\\DLCVNLP\\Practice Datasets\\BankCustomers.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Dealing with Numerical Variables
numerical = [var for var in df.columns if df[var].dtype != 'O']
print('There are {} numerical variables:\n'.format(len(numerical)))
print('The numerical variables are:\n\n', numerical)
# Out:
# There are 11 numerical variables:
#
# The numerical variables are:
#
#  ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %%
# Viewing the distribution of credit score variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['CreditScore']
ax = sns.distplot(x, bins = 10, color = 'yellow')
ax.set_title('Distribution of Credit Score')
plt.show()

# %%
# Viewing the distribution of Age variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['Age']
ax = sns.distplot(x, bins = 10, color = 'Blue')
ax.set_title('Distribution of Age variable')
plt.show()

# %%
# Viewing the distribution of Tenure variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['Tenure']
ax = sns.distplot(x, bins = 10, color = 'red')
ax.set_title('Distribution of Tenure variable')
plt.show()

# %%
# Viewing the distribution of Balance variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['Balance']
ax = sns.distplot(x, bins = 10, color = 'green')
ax.set_title('Distribution of Balance variable')
plt.show()

# %%
# Viewing the distribution of Number of Products
f, ax = plt.subplots(figsize = (10, 6))
x = df['NumOfProducts']
ax = sns.distplot(x, bins = 10, color = 'yellow')
ax.set_title('Distribution of Number of products')
plt.show()

# %%
# Viewing the distribution of Credit Card variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['HasCrCard']
ax = sns.distplot(x, bins = 10, color = 'green')
ax.set_title('Distribution of Credit Card variable')
plt.show()

# %%
# Viewing the distribution of Salary variable
f, ax = plt.subplots(figsize = (10, 6))
x = df['EstimatedSalary']
ax = sns.distplot(x, bins = 10, color = 'purple')
ax.set_title('Distribution of Salary variable')
plt.show()

# %%
# Dealing with Categorical Variables
categorical = [var for var in df.columns if df[var].dtype == 'O']
print('There are {} categorical variables:\n'.format(len(categorical)))
print('The categorical variables are:\n\n', categorical)
# Out:
# There are 3 categorical variables:
#
# The categorical variables are:
#
#  ['Surname', 'Geography', 'Gender']

# %%
# Finding Correlations
corr = df.corr()

f, ax = plt.subplots(figsize = (9, 6))
sns.heatmap(corr, annot = True, linewidths = 1.5, fmt = '.2f', ax= ax)
plt.show()

# %%
# Finding out the Status of the Customers
labels = 'Exited', 'Retained'
sizes = [df.Exited[df['Exited']==1].count(), df.Exited[df['Exited']==0].count()]
explode = (0, 0.1) #Transform each element of a list-like to a row, replicating index values
fig1, ax1 = plt.subplots(figsize = (10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow = True, startangle = 90)
ax1.axis('equal')
plt.title('Status of Customers', size = 15)
plt.show()

# %%
# Visualising Geography and Status of the customers
f, ax = plt.subplots(figsize = (10, 8))
ax = sns.countplot(x = "Exited", hue = "Geography", data = df, palette = "Set1")
ax.set_title("Distribution of Goegraphy and Status")
plt.show()

# %%
# Visualising Gender and Status of the customers
f, ax = plt.subplots(figsize = (10, 8))
ax = sns.countplot(x = "Exited", hue = "Gender", data = df, palette = "Set1")
ax.set_title("Distribution of Gender and Status")
plt.show()

# %%
# Visualising Credit Card and Status of the customers
f, ax = plt.subplots(figsize = (10, 8))
ax = sns.countplot(x = "Exited", hue = "HasCrCard", data = df, palette = "Set1")
ax.set_title("Distribution of Credit Card and Status")
plt.show()

# %%
# Visualising Active Member and Status of the customers
f, ax = plt.subplots(figsize = (10, 8))
ax = sns.countplot(x = "Exited", hue = "IsActiveMember", data = df, palette = "Set1")
ax.set_title("Distribution of Active Member and Status")
plt.show()

# %%
# Relation between Age and Status
sns.boxplot(x = "Exited", y = "Age", hue = "Exited", data = df)

# %%
# Relation between Tenure and Status
sns.boxplot(x = "Exited", y = "Tenure", hue = "Exited", data = df)

# %%
# Relation between Balance and Status
sns.boxplot(x = "Exited", y = "Balance", hue = "Exited", data = df)

# %%
# Relation between Estimated Salary and Status
sns.boxplot(x = "Exited", y = "EstimatedSalary", hue = "Exited", data = df)

# %%
# Checking for missing values in the dataset
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Visualizing the missing variables
sns.heatmap(df.isnull(), cbar = False)

# %% [markdown]
# # Detecting Outliers in the Dataset

# %%
# Deteting outliers in Credit Score variable
f, ax = plt.subplots(figsize = (10, 8))
x = df['CreditScore']
ax = sns.boxplot(x)
ax.set_title("visualizing outliers in Credit Score variable")
plt.show()

# %%
# Deteting outliers in Age variable
f, ax = plt.subplots(figsize = (10, 8))
x = df['Age']
ax = sns.boxplot(x)
ax.set_title("visualizing outliers in Age variable")
plt.show()

# %%
# Deteting outliers in Number of products variable
f, ax = plt.subplots(figsize = (10, 8))
x = df['NumOfProducts']
ax = sns.boxplot(x)
ax.set_title("visualizing outliers in Number of Products variable")
plt.show()

# %%
# Function to remove outlier
def remove_outlier(df, col_name):
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df.loc[(df[col_name] > fence_low) & (df[col_name] < fence_high)]
    return df_out

# %%
# Removing Outliers in Age, Credit score and Number of Products variables
remove_outlier(df, 'CreditScore')
remove_outlier(df, 'Age')
remove_outlier(df, 'NumOfProducts')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Let's remove the unwanted columns from the data set
X = df.iloc[:, 3:13].values
y = df.iloc[:, 13].values

# %%
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
# Label Encoding Categorical Variables
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
X[:, 1] = labelencoder.fit_transform(X[:, 1])
labelencoder1 = LabelEncoder()
X[:, 2] = labelencoder1.fit_transform(X[:, 2])

# %%
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Data Splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (7500, 10)
# Shape of X_test: (2500, 10)
# Shape of y_train: (7500,)
# Shape of y_test: (2500,)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Modelling

# %%
# SVM Classifier
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rfc.fit(X_train, y_train)
pred_rfc = rfc.predict(X_test)

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
dtree.fit(X_train, y_train)
pred_dtree = dtree.predict(X_test)

# %%
# Naive Bayes 
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
pred_gnb = gnb.predict(X_test)

# %%
# XGB
from xgboost import XGBClassifier
xgb = XGBClassifier(base_score = 0.5, booster = 'gbtree', colsample_bylevel = 1, colsample_bytree = 1,
                   gamma = 0.01, learning_rate = 0.1, max_delta_step = 0, max_depth = 7, min_child_weight = 5,
                   missing = None, n_estimators = 20, n_jobs = 1, nthread = None, objective = 'binary:logistic',
                   random_state = 0, reg_alpha = 0, reg_lambda = 1, scale_pos_weight = 1, seed = None,
                   silent = True, subsample = 1)
xgb.fit(X_train, y_train)
pred_xgb = xgb.predict(X_test)
# Out:
# [21:46:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %% [markdown]
# ## Model Evaluation

# %%
# Classification Report and Accuracy Score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Reports for SVM Classifier
print(classification_report(y_test, pred_svc))
print(accuracy_score(y_test, pred_svc))
print(confusion_matrix(y_test, pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1991
#            1       0.83      0.41      0.55       509
#
#     accuracy                           0.86      2500
#    macro avg       0.85      0.69      0.73      2500
# weighted avg       0.86      0.86      0.84      2500
#
# 0.862
# [[1947   44]
#  [ 301  208]]

# %%
# Reports for Random Forest Classifier
print(classification_report(y_test, pred_rfc))
print(accuracy_score(y_test, pred_rfc))
print(confusion_matrix(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1991
#            1       0.72      0.49      0.58       509
#
#     accuracy                           0.86      2500
#    macro avg       0.80      0.72      0.75      2500
# weighted avg       0.85      0.86      0.85      2500
#
# 0.8564
# [[1894   97]
#  [ 262  247]]

# %%
# Reports for Decision Tree Classifier
print(classification_report(y_test, pred_dtree))
print(accuracy_score(y_test, pred_dtree))
print(confusion_matrix(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1991
#            1       0.49      0.53      0.51       509
#
#     accuracy                           0.79      2500
#    macro avg       0.68      0.70      0.69      2500
# weighted avg       0.80      0.79      0.80      2500
#
# 0.7924
# [[1709  282]
#  [ 237  272]]

# %%
# Reports for Naive Bayes
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
print(confusion_matrix(y_test, pred_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      1991
#            1       0.70      0.25      0.37       509
#
#     accuracy                           0.83      2500
#    macro avg       0.77      0.61      0.64      2500
# weighted avg       0.81      0.83      0.79      2500
#
# 0.826
# [[1936   55]
#  [ 380  129]]

# %%
# Reports for XGB Classifier
print(classification_report(y_test, pred_xgb))
print(accuracy_score(y_test, pred_xgb))
print(confusion_matrix(y_test, pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      1991
#            1       0.73      0.51      0.60       509
#
#     accuracy                           0.86      2500
#    macro avg       0.81      0.73      0.76      2500
# weighted avg       0.85      0.86      0.85      2500
#
# 0.8612
# [[1895   96]
#  [ 251  258]]

# %%
# Visualizing Confusion Matrices
svm_cm = confusion_matrix(y_test, pred_svc)
rfc_cm = confusion_matrix(y_test, pred_rfc)
dtree_cm = confusion_matrix(y_test, pred_dtree)
gnb_cm = confusion_matrix(y_test, pred_gnb)
xgb_cm = confusion_matrix(y_test, pred_xgb)

fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(3, 3, 1) 
ax1.set_title('SVM Classification') 
ax2 = fig.add_subplot(3, 3, 2) 
ax2.set_title('Random Forest Classification')
ax3 = fig.add_subplot(3, 3, 3)
ax3.set_title('Decision Tree Classification')
ax4 = fig.add_subplot(3, 3, 4)
ax4.set_title('Naive Bayes Classification')
ax5 = fig.add_subplot(3, 3, 5)
ax5.set_title('XGB Classification')

sns.heatmap(data=svm_cm, annot=True, linewidth=0.7, linecolor='red',cmap="BuPu" ,fmt='g', ax=ax1)
sns.heatmap(data=rfc_cm, annot=True, linewidth=0.7, linecolor='red',cmap="BuPu" ,fmt='g', ax=ax2)  
sns.heatmap(data=dtree_cm, annot=True, linewidth=0.7, linecolor='red',cmap="BuPu" ,fmt='g', ax=ax3)
sns.heatmap(data=gnb_cm, annot=True, linewidth=0.7, linecolor='red',cmap="BuPu" ,fmt='g', ax=ax4)
sns.heatmap(data=xgb_cm, annot=True, linewidth=0.7, linecolor='red',cmap="BuPu" ,fmt='g', ax=ax5)

plt.show()

# %%
import scikitplot as skplt

# %%
# Precision Recall Curve
# SVC
from sklearn.svm import SVC
svc = SVC(probability = True)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)

y_pred_test  =svc.predict_proba(X_test)
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_test)

skplt.metrics.plot_cumulative_gain(y_test,y_pred_test)
skplt.metrics.plot_lift_curve(y_test,y_pred_test)
skplt.metrics.plot_roc (y_test,y_pred_test)
y_pred_test  = svc.predict_proba(X_test)
skplt.metrics.plot_ks_statistic(y_test,y_pred_test)
# Out:
# C:\Users\SRIRAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Precision Recall Curve for Random Forest Classifier
y_pred_test  =rfc.predict_proba(X_test)
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_test)

skplt.metrics.plot_cumulative_gain(y_test,y_pred_test)
skplt.metrics.plot_lift_curve(y_test,y_pred_test)
skplt.metrics.plot_roc (y_test,y_pred_test)
y_pred_test  = rfc.predict_proba(X_test)
skplt.metrics.plot_ks_statistic(y_test,y_pred_test)
# Out:
# C:\Users\SRIRAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Precision Recall curve for Decision Tree
y_pred_test  =dtree.predict_proba(X_test)
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_test)

skplt.metrics.plot_cumulative_gain(y_test,y_pred_test)
skplt.metrics.plot_lift_curve(y_test,y_pred_test)
skplt.metrics.plot_roc (y_test,y_pred_test)
y_pred_test  = dtree.predict_proba(X_test)
skplt.metrics.plot_ks_statistic(y_test,y_pred_test)
# Out:
# C:\Users\SRIRAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Precision Recall Curve for Naive Bayes
y_pred_test  =gnb.predict_proba(X_test)
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_test)

skplt.metrics.plot_cumulative_gain(y_test,y_pred_test)
skplt.metrics.plot_lift_curve(y_test,y_pred_test)
skplt.metrics.plot_roc (y_test,y_pred_test)
y_pred_test  = gnb.predict_proba(X_test)
skplt.metrics.plot_ks_statistic(y_test,y_pred_test)
# Out:
# C:\Users\SRIRAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Precision Recall Curve for XGB
y_pred_test  =xgb.predict_proba(X_test)
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_test)

skplt.metrics.plot_cumulative_gain(y_test,y_pred_test)
skplt.metrics.plot_lift_curve(y_test,y_pred_test)
skplt.metrics.plot_roc (y_test,y_pred_test)
y_pred_test  = xgb.predict_proba(X_test)
skplt.metrics.plot_ks_statistic(y_test,y_pred_test)
# Out:
# C:\Users\SRIRAM\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## HyperParameter Tuning

# %%
# Hyper Parameter Tuning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from scipy.stats import uniform

# %%
# Function to get the best score
def get_best_score(model):
    
    print(model.best_score_)    
    print(model.best_params_)
    print(model.best_estimator_)
    
    return model.best_score_

# %%
# Tuning Decision Tree
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

param_grid = {'min_samples_split':[4, 7, 10, 12]}
dtree_grid = GridSearchCV(dtree, param_grid, cv = 10, refit = True, verbose = 1)
dtree_grid.fit(X, y)

print(dtree_grid.best_score_)
print(dtree_grid.best_params_)
print(dtree_grid.best_estimator_)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 0.8126999999999999
# {'min_samples_split': 12}
# DecisionTreeClassifier(min_samples_split=12)
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    1.3s finished

# %%
# Tuning XGB
from xgboost import XGBClassifier
xgb = XGBClassifier()
param_grid = {'max_depth':[5, 6, 7, 8],
             'gamma':[1, 2, 4],
             'learning_rate':[0.1, 0.2, 0.3, 0.5]}


xgb_grid = GridSearchCV(xgb, param_grid, cv = 10, refit = True, verbose = 1)
xgb_grid.fit(X, y)
sc_xgb = get_best_score(xgb_grid)
# Out:
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed:  4.8min finished
# 0.8648
# {'gamma': 2, 'learning_rate': 0.2, 'max_depth': 5}
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=2, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.2, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Tuning for Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

param_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [6,7,8,9,10],  
              'min_samples_split': [5, 6, 7, 8]}

rf_grid = GridSearchCV(rfc, param_grid, cv=10, refit=True, verbose=1)
rf_grid.fit(X, y)
sc_rf = get_best_score(rf_grid)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed: 17.6min finished
# 0.8619
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 8}
# RandomForestClassifier(max_depth=8, max_features=8, min_samples_split=8)
